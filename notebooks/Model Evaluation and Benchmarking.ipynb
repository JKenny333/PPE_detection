# %%
pip install --upgrade ultralytics

# %%
import json
from IPython.display import JSON
from ultralytics import YOLO

# %%
model_path_s = "/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/small_yolo_model/ppe_s.pt"
model_path_m = "/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/medium_yolo_model/ppe_m.pt"
model_path_l = "/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.pt"
data_yaml = "/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Construction Site Safety.v27-yolov8.yolov8/data.yaml"
json_path = "/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/notebooks/runs/detect/val/predictions.json"

# %% [markdown]
# ## Exporting Model in different formats

# %%
model = YOLO(model_path_l)# load a custom model
#Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.6 torch-2.2.1 CPU (Apple M2)
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
#
# PyTorch: starting from '/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (83.6 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 1.3s, saved as '/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.onnx' (166.6 MB)
#
# Export complete (2.6s)
# Results saved to /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model
# Predict:         yolo predict task=detect model=/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.onnx imgsz=640
# Validate:        yolo val task=detect model=/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.onnx imgsz=640 data=/content/drive/MyDrive/Data Analytics/Projects/PPE detection/Data/Construction/Construction Site Safety/data.yaml
# Visualize:       https://netron.app
# '/Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/models/large_yolo_model/ppe_l.onnx'

# %%
# Load model
model = YOLO(model_path_s)  # load a custom model

# Validate the model
metrics = model.val(data=data_yaml, conf=0.25, plots=True, save_json=True, device="cpu")  # no arguments needed, dataset and settings remembered
print(f'mAP 50-95: {metrics.box.map}')  # map50-95
print(f'mAP 50: {metrics.box.map50}')  # map50
print(f'mAP 75: {metrics.box.map75}') # map75
print("List of map50-95 for each category:")
print(metrics.box.maps)   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.6 torch-2.2.1 CPU (Apple M2)
# Model summary (fused): 168 layers, 11129454 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Con
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        114        697      0.927      0.743      0.857      0.607
#                Hardhat        114         79      0.942      0.772      0.891      0.632
#                   Mask        114         21          1      0.902       0.95      0.752
#             NO-Hardhat        114         69      0.893       0.58      0.772      0.502
#                NO-Mask        114         74       0.96      0.642      0.802      0.482
#         NO-Safety Vest        114        106       0.95      0.715       0.83      0.599
#                 Person        114        166      0.915      0.777      0.856        0.6
#            Safety Cone        114         44      0.896      0.818      0.882       0.57
#            Safety Vest        114         41      0.941      0.776      0.904      0.646
#              machinery        114         55      0.946      0.873      0.958      0.707
#                vehicle        114         42      0.832      0.571      0.728      0.582
# Speed: 0.8ms preprocess, 341.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Saving runs/detect/val/predictions.json...
# Results saved to runs/detect/val
# mAP 50-95: 0.6072716622679032
# mAP 50: 0.8572455232184761
# mAP 75: 0.7091865599148361
# List of map50-95 for each category:
# [    0.63167     0.75228       0.502     0.48224     0.59895     0.59953     0.57015       0.646     0.70747     0.58243]

# %%
# Load model
model = YOLO(model_path_m)  # load a custom model

# Validate the model
metrics = model.val(data=data_yaml, conf=0.25, plots=True, save_json=True, device="cpu")  # no arguments needed, dataset and settings remembered
print(f'mAP 50-95: {metrics.box.map}')  # map50-95
print(f'mAP 50: {metrics.box.map50}')  # map50
print(f'mAP 75: {metrics.box.map75}') # map75
print("List of map50-95 for each category:")
print(metrics.box.maps)   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.6 torch-2.2.1 CPU (Apple M2)
# Model summary (fused): 218 layers, 25845550 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Con
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        114        697      0.935      0.789       0.88      0.644
#                Hardhat        114         79      0.967      0.797      0.894      0.641
#                   Mask        114         21          1      0.905      0.952       0.76
#             NO-Hardhat        114         69      0.914      0.594      0.748      0.495
#                NO-Mask        114         74      0.901      0.736      0.849      0.575
#         NO-Safety Vest        114        106      0.938      0.714      0.843      0.626
#                 Person        114        166      0.951      0.815      0.893      0.656
#            Safety Cone        114         44      0.963      0.909       0.95      0.623
#            Safety Vest        114         41      0.924       0.89      0.938      0.717
#              machinery        114         55      0.963      0.934      0.978      0.762
#                vehicle        114         42      0.833      0.595      0.755      0.581
# Speed: 0.9ms preprocess, 821.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Saving runs/detect/val/predictions.json...
# Results saved to runs/detect/val
# mAP 50-95: 0.6436831390131842
# mAP 50: 0.8798454249406429
# mAP 75: 0.7491817573062217
# List of map50-95 for each category:
# [    0.64093     0.76023     0.49469     0.57516     0.62586     0.65615     0.62341     0.71683     0.76248     0.58108]

# %%
# Load model
model = YOLO(model_path_l)  # load a custom model

# Validate the model
metrics = model.val(data=data_yaml, conf=0.25, plots=True, save_json=True, device="cpu")  # no arguments needed, dataset and settings remembered
print(f'mAP 50-95: {metrics.box.map}')  # map50-95
print(f'mAP 50: {metrics.box.map50}')  # map50
print(f'mAP 75: {metrics.box.map75}') # map75
print("List of map50-95 for each category:")
print(metrics.box.maps)   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.6 torch-2.2.1 CPU (Apple M2)
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Con
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        114        697      0.925        0.8      0.883      0.658
#                Hardhat        114         79      0.955       0.81      0.894      0.672
#                   Mask        114         21       0.95      0.905       0.95      0.766
#             NO-Hardhat        114         69      0.857       0.61      0.759      0.522
#                NO-Mask        114         74      0.936       0.73      0.844      0.583
#         NO-Safety Vest        114        106      0.921      0.755       0.85      0.618
#                 Person        114        166      0.936      0.819      0.901      0.658
#            Safety Cone        114         44      0.967      0.886      0.936      0.633
#            Safety Vest        114         41      0.896      0.844      0.913      0.715
#              machinery        114         55      0.981      0.964       0.98      0.787
#                vehicle        114         42      0.851      0.678      0.799      0.627
# Speed: 0.8ms preprocess, 1214.9ms inference, 0.0ms loss, 0.3ms postprocess per image
# Saving runs/detect/val/predictions.json...
# Results saved to runs/detect/val
# mAP 50-95: 0.6579497644423618
# mAP 50: 0.8826716713654766
# mAP 75: 0.7660155355964876
# List of map50-95 for each category:
# [    0.67201     0.76584     0.52212     0.58286     0.61801     0.65764     0.63267     0.71452     0.78697     0.62686]

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on CPU
benchmark(model=model_path_s, data=data_yaml, device="cpu")
# Out:
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 146.9/460.4 GB disk)
#
# Benchmarks complete for ppe_s.pt on /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Construction Site Safety.v27-yolov8.yolov8/data.yaml at imgsz=160 (8.66s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       21.5               0.2417                   21.87
# 1             TorchScript       ✅       42.8               0.2343                   18.24
# 2                    ONNX       ❎       42.5                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       21.5               0.2417                   21.87
# 1             TorchScript       ✅       42.8               0.2343                   18.24
# 2                    ONNX       ❎       42.5                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN

# %%
# Benchmark on CPU
benchmark(model=model_path_m, data=data_yaml, device="cpu")
# Out:
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 146.2/460.4 GB disk)
#
# Benchmarks complete for ppe_m.pt on /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Construction Site Safety.v27-yolov8.yolov8/data.yaml at imgsz=160 (13.60s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       49.6               0.2577                   44.08
# 1             TorchScript       ✅       99.0               0.2436                   31.13
# 2                    ONNX       ❎       98.7                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       49.6               0.2577                   44.08
# 1             TorchScript       ✅       99.0               0.2436                   31.13
# 2                    ONNX       ❎       98.7                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN

# %%
# Benchmark on CPU
benchmark(model=model_path_l, data=data_yaml, device="cpu")
# Out:
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 146.6/460.4 GB disk)
#
# Benchmarks complete for ppe_l.pt on /Users/jameskenny/Documents/GitHub/Ironhack/PPE_detection/data/Construction Site Safety.v27-yolov8.yolov8/data.yaml at imgsz=160 (19.85s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       83.6               0.2639                   62.34
# 1             TorchScript       ✅      166.9               0.2536                   52.70
# 2                    ONNX       ❎      166.5                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       83.6               0.2639                   62.34
# 1             TorchScript       ✅      166.9               0.2536                   52.70
# 2                    ONNX       ❎      166.5                  NaN                     NaN
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ❌        0.0                  NaN                     NaN
# 12                   NCNN       ❌        0.0                  NaN                     NaN
